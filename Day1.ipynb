# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat-2923/DBMS-Lab/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10+30);
